# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
x = df.drop(['charges'],axis='columns')
y = df['charges']

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
s = LabelEncoder()
smo = LabelEncoder()
r = LabelEncoder()

# %%
x['gender'] = s.fit_transform(x['sex'])
x['smoke'] = s.fit_transform(x['smoker'])
x['area'] = s.fit_transform(x['region'])

# %%
x.head()
# Out:
#    age     sex     bmi  children smoker     region  gender  smoke  area
# 0   19  female  27.900         0    yes  southwest       0      1     3
# 1   18    male  33.770         1     no  southeast       1      0     2
# 2   28    male  33.000         3     no  southeast       1      0     2
# 3   33    male  22.705         0     no  northwest       1      0     1
# 4   32    male  28.880         0     no  northwest       1      0     1

# %%
xx = x.drop(['sex','smoker','region'],axis = 'columns')
xx.head()
# Out:
#    age     bmi  children  gender  smoke  area
# 0   19  27.900         0       0      1     3
# 1   18  33.770         1       1      0     2
# 2   28  33.000         3       1      0     2
# 3   33  22.705         0       1      0     1
# 4   32  28.880         0       1      0     1

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(xx, y, test_size=0.1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.7499234207698997

# %%
X_test['ans']=model.predict(X_test)

# %%
X_test
# Out:
#       age     bmi  children  gender  smoke  area           ans
# 408    38  21.120         3       1      0     2   5585.545872
# 655    52  25.300         2       0      1     2  34069.785650
# 556    46  33.440         1       1      0     0  11640.396387
# 521    32  44.220         0       0      0     2  10541.907269
# 1074   60  18.335         0       0      0     0   9802.707912
# ...   ...     ...       ...     ...    ...   ...           ...
# 121    18  23.750         0       1      0     0    647.976109
# 125    26  28.785         0       0      0     0   4445.894723
# 883    51  37.050         3       0      1     0  38851.739777
# 989    24  20.520         0       0      1     0  24972.689828
# 978    45  39.995         3       0      0     0  14446.225009
#
# [134 rows x 7 columns]
